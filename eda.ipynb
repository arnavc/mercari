# %%
import pandas as pd

# %%
sample_sub = pd.read_csv('data/sample_submission.csv')

# %%
print(sample_sub)
# Out:
#         test_id   price
# 0             0  26.738
# 1             1  26.738
# 2             2  26.738
# 3             3  26.738
# 4             4  26.738
# 5             5  26.738
# 6             6  26.738
# 7             7  26.738
# 8             8  26.738
# 9             9  26.738
# 10           10  26.738
# 11           11  26.738
# 12           12  26.738
# 13           13  26.738
# 14           14  26.738
# 15           15  26.738
# 16           16  26.738
# 17           17  26.738
# 18           18  26.738
# 19           19  26.738
# 20           20  26.738
# 21           21  26.738
# 22           22  26.738
# 23           23  26.738
# 24           24  26.738
# 25           25  26.738
# 26           26  26.738
# 27           27  26.738
# 28           28  26.738
# 29           29  26.738
# ...         ...     ...
# 693329   693329  26.738
# 693330   693330  26.738
# 693331   693331  26.738
# 693332   693332  26.738
# 693333   693333  26.738
# 693334   693334  26.738
# ...

# %%
print(sample_sub.shape)
# Out:
# (693359, 2)

# %%
train = pd.read_csv('data/train.tsv', sep = '\t')

# %%
print(train.shape)
# Out:
# (1482535, 8)

# %%
train.head(100)
# Out:
#     train_id                                      name  item_condition_id  \
# 0          0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1          1          Razer BlackWidow Chroma Keyboard                  3
# 2          2                            AVA-VIV Blouse                  1
# 3          3                     Leather Horse Statues                  1
# 4          4                      24K GOLD plated rose                  1
# 5          5          Bundled items requested for Ruie                  3
# 6          6        Acacia pacific tides santorini top                  3
# 7          7      Girls cheer and tumbling bundle of 7                  3
# 8          8                     Girls Nike Pro shorts                  3
# 9          9    Porcelain clown doll checker pants VTG                  3
# 10        10                           Smashbox primer                  2
# 11        11                    New vs pi k body mists                  1
# ...

# %%
train['name'][train['price']==2009.0]
# Out:
# 760469    NEW Chanel WOC Caviar Gold Hardware
# Name: name, dtype: object

# %%
train['price'].mean()
# Out:
# 26.737516146330442

# %%
#number of unique brands
len(train['brand_name'].unique())
# Out:
# 4810

# %%
from collections import Counter

# %%
#Use counter to list brands and the number of times they appear
brand_count = Counter(train['brand_name'])
print(brand_count)
# Out:
# Counter({nan: 632682, 'PINK': 54088, 'Nike': 54043, "Victoria's Secret": 48036, 'LuLaRoe': 31024, 'Apple': 17322, 'FOREVER 21': 15186, 'Nintendo': 15007, 'Lululemon': 14558, 'Michael Kors': 13928, 'American Eagle': 13254, 'Rae Dunn': 12305, 'Sephora': 12172, 'Coach': 10463, 'Disney': 10360, 'Bath & Body Works': 10354, 'Adidas': 10202, 'Funko': 9237, 'Under Armour': 8461, 'Sony': 7994, 'Old Navy': 7567, 'Hollister': 6948, "Carter's": 6385, 'Urban Decay': 6210, 'The North Face': 6172, 'Independent': 5902, 'Too Faced': 5794, 'Xbox': 5709, 'Brandy Melville': 5680, 'Kate Spade': 5411, 'MAC': 5302, 'Kendra Scott': 5097, 'Gap': 5088, 'Tarte': 4984, 'UGG Australia': 4676, 'VANS': 4588, 'Polo Ralph Lauren': 4547, 'Charlotte Russe': 4177, 'Samsung': 4077, 'SeneGence': 4045, 'Vera Bradley': 4036, 'Ralph Lauren': 4007, 'Converse': 3978, 'H&M': 3748, 'Air Jordan': 3511, 'Free People': 3483, 'Tory Burch': 3447, 'Miss Me': 3270, 'Express': 3211, 'Louis Vuitton': 3187, 'Abercrombie & Fitch': 3156, '
# ...

# %%
max(brand_count.values())
# Out:
# 632682

# %%
sort
# Out:
# dict_values([632682, 94, 1868, 451, 151, 54043, 1335, 48036, 932, 18, 4676, 4984, 1168, 5794, 932, 2388, 4077, 15186, 3511, 17322, 31024, 6948, 54088, 12172, 8461, 5709, 2755, 6172, 5680, 1009, 13928, 12305, 175, 2741, 1807, 1250, 3748, 10202, 75, 1461, 2, 734, 254, 3062, 15007, 557, 549, 5088, 14558, 1876, 1538, 996, 2, 1049, 2221, 670, 497, 3270, 280, 1881, 10354, 1235, 17, 4007, 499, 5411, 1479, 376, 243, 2657, 7994, 237, 1936, 1653, 4, 331, 2774, 95, 161, 10360, 24, 1256, 2160, 1530, 7567, 17, 213, 386, 511, 4, 1159, 1008, 84, 1550, 555, 13254, 275, 815, 398, 5097, 305, 215, 1712, 9237, 1469, 10463, 155, 1181, 26, 3483, 2016, 101, 8, 3447, 948, 991, 1863, 5902, 3116, 4036, 285, 3065, 951, 4045, 3211, 494, 68, 292, 160, 218, 12, 298, 1675, 4177, 1060, 773, 456, 57, 87, 2028, 1072, 564, 1031, 772, 469, 61, 1683, 3978, 12, 1666, 861, 2035, 84, 937, 927, 2481, 363, 977, 143, 1232, 4547, 2353, 9, 767, 3, 2283, 1563, 87, 4, 333, 149, 1751, 818, 914, 429, 77, 1706, 20, 18, 5302, 789, 25
# ...

# %%
Counter(train['category_name'])
# Out:
# Counter({'Men/Tops/T-shirts': 15108,
#          'Electronics/Computers & Tablets/Components & Parts': 964,
#          'Women/Tops & Blouses/Blouse': 20284,
#          'Home/Home Décor/Home Décor Accents': 13004,
#          'Women/Jewelry/Necklaces': 19758,
#          'Women/Other/Other': 7264,
#          'Women/Swimwear/Two-Piece': 12758,
#          'Sports & Outdoors/Apparel/Girls': 545,
#          'Vintage & Collectibles/Collectibles/Doll': 789,
#          'Beauty/Makeup/Face': 34335,
#          'Beauty/Fragrance/Women': 18628,
#          'Women/Dresses/Above Knee, Mini': 20082,
#          'Other/Office supplies/School Supplies': 1901,
#          'Women/Shoes/Boots': 18864,
#          'Beauty/Makeup/Makeup Sets': 6175,
#          'Beauty/Makeup/Eyes': 25215,
#          'Kids/Gear/Backpacks & Carriers': 1921,
#          'Beauty/Makeup/Makeup Palettes': 19103,
#          'Women/Tops & Blouses/Tank, Cami': 20284,
#          'Women/Athletic Apparel/Sports Bras': 9067,
# ...

# %%
#counts the number of items with no descriptions yet
pd.value_counts(train['item_description'] == 'No description yet')
# Out:
# False    1400046
# True       82489
# Name: item_description, dtype: int64
